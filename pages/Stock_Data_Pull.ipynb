# %%
autoname = {
    'TSLA':'Tesla',
    'TM':'Toyota Motors',
    'RACE':'Ferrari',
    'GM':'General Motors',
    'HMC':'Honda Motors Company',
    'FUV':'Arcimoto',
    'NVDA':'Nvidia',
    'HOG':'Harley Davidson',
    'FCAU':'Fiat Chrysler',
    'F':'Ford',
    'KNDI':'Kandi Technologies Inc',
    'NIO':'NIO',
    'TTM':'Tata Motors',
    'SPAR':'Spartan Motors',
    'WKHS':'Workhorse Group Inc',
    'GOOGL':'Alpabet / Google'
}

autoname['TSLA']
# Out:
# 'Tesla'

# %%
from datetime import datetime
from concurrent import futures
import matplotlib.pyplot as plt

import pandas as pd
from pandas import DataFrame
import pandas_datareader.data as web


auto = ['TSLA','TM','NVDA','RACE','GM','HMC','FUV','HOG','FCAU','F','KNDI',
        'NIO','TTM','SPAR','WKHS','GOOGL']

autoname = {
    'TSLA':'Tesla',
    'TM':'Toyota Motors',
    'RACE':'Ferrari',
    'GM':'General Motors',
    'HMC':'Honda Motors Company',
    'FUV':'Arcimoto',
    'NVDA':'Nvidia',
    'HOG':'Harley Davidson',
    'FCAU':'Fiat Chrysler',
    'F':'Ford',
    'KNDI':'Kandi Technologies Inc',
    'NIO':'NIO',
    'TTM':'Tata Motors',
    'SPAR':'Spartan Motors',
    'WKHS':'Workhorse Group Inc',
    'GOOGL':'Alpabet / Google'
}

now_time = datetime.now()
start_time = datetime(now_time.year - 1, now_time.month , now_time.day)
stock_df=[]
df = pd.DataFrame([])
stockplot=[]


for x in auto:
    print(x)
    stock_df = web.DataReader(x,'iex', start_time, now_time)
    stock_df['Name'] = x
    stock_df['RealName'] = autoname[x]
    df = df.append(stock_df)
    stockplot = stock_df.drop(['high','low','volume','close'],axis=1)
    RealName=stockplot['RealName']
    stockplot.plot()
    plt.title(x)
# Out:
# TSLA
# TM
# NVDA
# RACE
# GM
# HMC
# FUV
# HOG
# FCAU
# F
# KNDI
# NIO
# TTM
# SPAR
# WKHS
# GOOGL

# %%
pd.DataFrame.head(stock_df)
# Out:
#                open     high      low    close   volume   Name  \
# date
# 2018-01-16  1140.31  1148.88  1126.66  1130.70  1823100  GOOGL
# 2018-01-17  1136.36  1139.32  1123.49  1139.10  1391510  GOOGL
# 2018-01-18  1139.35  1140.59  1124.46  1135.97  1374873  GOOGL
# 2018-01-19  1138.03  1143.78  1132.50  1143.50  1527554  GOOGL
# 2018-01-22  1143.82  1166.88  1141.82  1164.16  1477520  GOOGL
#
#                     RealName
# date
# 2018-01-16  Alpabet / Google
# 2018-01-17  Alpabet / Google
# 2018-01-18  Alpabet / Google
# 2018-01-19  Alpabet / Google
# 2018-01-22  Alpabet / Google

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

for x in auto:
    y = df[df['Name']==x]
    plt.plot(y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-07bda81e1f78> in <module>()
#       5 for x in auto:
#       6     y = df[df['Name']==x]
# ----> 7     plt.plot(y)
#
# ~\Anaconda\lib\site-packages\matplotlib\pyplot.py in plot(*args, **kwargs)
#    3259                       mplDeprecation)
#    3260     try:
# -> 3261         ret = ax.plot(*args, **kwargs)
#    3262     finally:
#    3263         ax._hold = washold
#
# ~\Anaconda\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1715                     warnings.warn(msg % (label_namer, func.__name__),
#    1716                                   RuntimeWarning, stacklevel=2)
# -> 1717             return func(ax, *args, **kwargs)
#    1718         pre_doc = inner.__doc__
#    1719         if pre_doc is None:
#
# ~\Anaconda\lib\site-packages\matplotlib\axes\_axes.py in plot(self, *args, **kwargs)
#    1371
#    1372         for line in self._get_lines(*args, **kwargs):
# -> 1373             self.add_line(line)
#    1374             lines.append(line)
#    1375
#
# ~\Anaconda\lib\site-packages\matplotlib\axes\_base.py in add_line(self, line)
#    1777             line.set_clip_path(self.patch)
#    1778
# -> 1779         self._update_line_limits(line)
#    1780         if not line.get_label():
#    1781             line.set_label('_line%d' % len(self.lines))
#
# ~\Anaconda\lib\site-packages\matplotlib\axes\_base.py in _update_line_limits(self, line)
#    1799         Figures out the data limit of the given line, updating self.dataLim.
#    1800         """
# -> 1801         path = line.get_path()
#    1802         if path.vertices.size == 0:
#    1803             return
#
# ~\Anaconda\lib\site-packages\matplotlib\lines.py in get_path(self)
#     955         """
#     956         if self._invalidy or self._invalidx:
# --> 957             self.recache()
#     958         return self._path
#     959
#
# ~\Anaconda\lib\site-packages\matplotlib\lines.py in recache(self, always)
#     660             x = self._x
#     661         if always or self._invalidy:
# --> 662             yconv = self.convert_yunits(self._yorig)
#     663             y = _to_unmasked_float_array(yconv).ravel()
#     664         else:
#
# ~\Anaconda\lib\site-packages\matplotlib\artist.py in convert_yunits(self, y)
#     198         if ax is None or ax.yaxis is None:
#     199             return y
# --> 200         return ax.yaxis.convert_units(y)
#     201
#     202     @property
#
# ~\Anaconda\lib\site-packages\matplotlib\axis.py in convert_units(self, x)
#    1489             return x
#    1490
# -> 1491         ret = self.converter.convert(x, self.units, self)
#    1492         return ret
#    1493
#
# ~\Anaconda\lib\site-packages\matplotlib\category.py in convert(value, unit, axis)
#      47                 if isinstance(val, six.string_types):
#      48                     axis.unit_data.update(val)
# ---> 49         vmap = dict(zip(axis.unit_data.seq, axis.unit_data.locs))
#      50
#      51         if isinstance(value, six.string_types):
#
# AttributeError: 'NoneType' object has no attribute 'seq'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\Anaconda\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~\Anaconda\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     236
#     237     if 'png' in formats:
# --> 238         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     239     if 'retina' in formats or 'png2x' in formats:
#     240         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~\Anaconda\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     120
#     121     bytes_io = BytesIO()
# --> 122     fig.canvas.print_figure(bytes_io, **kw)
#     123     data = bytes_io.getvalue()
#     124     if fmt == 'svg':
#
# ~\Anaconda\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2216                     **kwargs)
#    2217                 renderer = self.figure._cachedRenderer
# -> 2218                 bbox_inches = self.figure.get_tightbbox(renderer)
#    2219
#    2220                 bbox_artists = kwargs.pop("bbox_extra_artists", None)
#
# ~\Anaconda\lib\site-packages\matplotlib\figure.py in get_tightbbox(self, renderer)
#    1981         for ax in self.axes:
#    1982             if ax.get_visible():
# -> 1983                 bb.append(ax.get_tightbbox(renderer))
#    1984
#    1985         if len(bb) == 0:
#
# ~\Anaconda\lib\site-packages\matplotlib\axes\_base.py in get_tightbbox(self, renderer, call_axes_locator)
#    4007
#    4008         if self.title.get_visible():
# -> 4009             bb.append(self.title.get_window_extent(renderer))
#    4010         if self._left_title.get_visible():
#    4011             bb.append(self._left_title.get_window_extent(renderer))
#
# ~\Anaconda\lib\site-packages\matplotlib\text.py in get_window_extent(self, renderer, dpi)
#     923             self.figure.dpi = dpi
#     924         if self.get_text() == '':
# --> 925             tx, ty = self._get_xy_display()
#     926             return Bbox.from_bounds(tx, ty, 0, 0)
#     927
#
# ~\Anaconda\lib\site-packages\matplotlib\text.py in _get_xy_display(self)
#     232     def _get_xy_display(self):
#     233         'get the (possibly unit converted) transformed x, y in display coords'
# --> 234         x, y = self.get_unitless_position()
#     235         return self.get_transform().transform_point((x, y))
#     236
#
# ~\Anaconda\lib\site-packages\matplotlib\text.py in get_unitless_position(self)
#     854         # This is here for convienience since it is done in several locations.
#     855         x = float(self.convert_xunits(self._x))
# --> 856         y = float(self.convert_yunits(self._y))
#     857         return x, y
#     858
#
# ~\Anaconda\lib\site-packages\matplotlib\artist.py in convert_yunits(self, y)
#     198         if ax is None or ax.yaxis is None:
#     199             return y
# --> 200         return ax.yaxis.convert_units(y)
#     201
#     202     @property
#
# ~\Anaconda\lib\site-packages\matplotlib\axis.py in convert_units(self, x)
#    1489             return x
#    1490
# -> 1491         ret = self.converter.convert(x, self.units, self)
#    1492         return ret
#    1493
#
# ~\Anaconda\lib\site-packages\matplotlib\category.py in convert(value, unit, axis)
#      47                 if isinstance(val, six.string_types):
#      48                     axis.unit_data.update(val)
# ---> 49         vmap = dict(zip(axis.unit_data.seq, axis.unit_data.locs))
#      50
#      51         if isinstance(value, six.string_types):
#
# AttributeError: 'NoneType' object has no attribute 'seq'
