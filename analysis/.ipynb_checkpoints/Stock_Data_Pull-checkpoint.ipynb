# %%
## Code by Eric Englin
## This is a project for Team B3 in Harvard Kennedy School Code 4 Policy course
# This jupyter notebook pulls historical NYSE stock data for major companies in the auto & tech industry
# Please note that many car companies do not participate in the NYSE, so these companies will not show up in this analysis

##Code originally forked from CNuge repo kaggle-code, stock data

# %%
from datetime import datetime
from concurrent import futures
import matplotlib.pyplot as plt

import pandas as pd
from pandas import DataFrame
import pandas_datareader.data as web


auto = ['TSLA','TM','NVDA','RACE','GM','HMC','FUV','HOG','FCAU','F','KNDI',
        'NIO','TTM','SPAR','WKHS','GOOGL']

autoname = {
    'TSLA':'Tesla',
    'TM':'Toyota',
    'RACE':'Ferrari',
    'GM':'GM',
    'HMC':'Honda',
    'FUV':'Arcimoto',
    'NVDA':'Nvidia',
    'HOG':'Harley Davidson',
    'FCAU':'Fiat Chrysler',
    'F':'Ford',
    'KNDI':'Kandi Technologies Inc',
    'NIO':'NIO',
    'TTM':'Tata Motors',
    'SPAR':'Spartan Motors',
    'WKHS':'Workhorse Group Inc',
    'GOOGL':'Google'
}

now_time = datetime.now()
start_time = datetime(now_time.year - 5, now_time.month , now_time.day)
stock_df=[]
df = pd.DataFrame([])
stockplot=[]


for x in auto:
    print(x)
    stock_df = web.DataReader(x,'iex', start_time, now_time)
    stock_df['Name'] = x
    stock_df['RealName'] = autoname[x]
    df = df.append(stock_df)
    stockplot = stock_df.drop(['high','low','volume','close'],axis=1)
    RealName=stockplot['RealName']
    stockplot.plot()
    plt.axis()
    plt.title(autoname[x])
    plt.show()
    
    a=2
# Out:
# TSLA
# TM
# NVDA
# RACE
# GM
# HMC
# FUV
# HOG
# FCAU
# F
# KNDI
# NIO
# TTM
# SPAR
# WKHS
# GOOGL

# %%
#Look at the table to ensure that table starts 5 years ago with Tesla
#Also want to make sure that RealName variable came through
pd.DataFrame.head(df)
# Out:
#               open     high      low   close   volume  Name RealName
# date
# 2014-01-17  170.19  173.200  167.950  170.01  9216028  TSLA    Tesla
# 2014-01-21  171.24  177.290  170.810  176.68  9745765  TSLA    Tesla
# 2014-01-22  177.81  180.319  174.760  178.56  7036758  TSLA    Tesla
# 2014-01-23  177.23  182.380  173.420  181.50  7899515  TSLA    Tesla
# 2014-01-24  177.85  180.480  173.531  174.60  7711296  TSLA    Tesla

# %%
#Look at tail to make sure it is yesterday with GOOGL
pd.DataFrame.tail(df)
# Out:
#                open     high      low    close   volume   Name  \
# date
# 2019-01-10  1074.94  1079.81  1064.68  1078.83  1329861  GOOGL
# 2019-01-11  1069.90  1073.37  1056.43  1064.47  1543238  GOOGL
# 2019-01-14  1053.34  1058.45  1048.55  1051.51  1424486  GOOGL
# 2019-01-15  1058.01  1088.27  1054.44  1086.51  1875852  GOOGL
# 2019-01-16  1090.00  1102.36  1088.01  1089.51  1914041  GOOGL
#
#                     RealName
# date
# 2019-01-10  Alpabet / Google
# 2019-01-11  Alpabet / Google
# 2019-01-14  Alpabet / Google
# 2019-01-15  Alpabet / Google
# 2019-01-16  Alpabet / Google

# %%
#Save as a final csv for data visualization
df.to_csv('../data/stock_5_years_rows.csv')

# %%
df_Tesla = df[df['Name']=='TSLA']
pd.DataFrame.tail(df_Tesla)
# Out:
#               open    high     low   close   volume  Name RealName
# date
# 2019-01-10  334.40  345.39  331.79  344.97  6056354  TSLA    Tesla
# 2019-01-11  342.09  348.41  338.77  347.26  5039052  TSLA    Tesla
# 2019-01-14  342.38  342.50  334.00  334.40  5247284  TSLA    Tesla
# 2019-01-15  335.00  348.80  334.50  344.43  6056590  TSLA    Tesla
# 2019-01-16  344.78  352.00  343.50  346.05  4691739  TSLA    Tesla

# %%
df_Tesla=df_Tesla.drop(['high','low','volume','open'],axis=1)

# %%
# We want our dates in 16-Apr-12 format
list(df_Tesla.columns.values)
# Out:
# ['close', 'Name', 'RealName']

# %%
#Building visualization specific to Telsa to start
#Save as a final csv for data visualization
df_Tesla.to_csv('../data/Tesla_Stock.csv')

# %%
df_Tesla.plot()

# %%
df_GM = df[df['Name']=='GM']
df_GM=df_GM.drop(['high','low','volume','open'],axis=1)
pd.DataFrame.tail(df_GM)
# Out:
#             close Name        RealName
# date
# 2019-01-11  37.18   GM  General Motors
# 2019-01-14  37.66   GM  General Motors
# 2019-01-15  37.55   GM  General Motors
# 2019-01-16  37.67   GM  General Motors
# 2019-01-17  38.26   GM  General Motors

# %%
df_GM.plot()

# %%
df_GM.to_csv('../data/GM_Stock.csv')

# %%
df_GOOGL = df[df['Name']=='GOOGL']
df_GOOGL=df_GOOGL.drop(['high','low','volume','open'],axis=1)
pd.DataFrame.tail(df_GOOGL)
# Out:
#               close   Name          RealName
# date
# 2019-01-11  1064.47  GOOGL  Alpabet / Google
# 2019-01-14  1051.51  GOOGL  Alpabet / Google
# 2019-01-15  1086.51  GOOGL  Alpabet / Google
# 2019-01-16  1089.51  GOOGL  Alpabet / Google
# 2019-01-17  1099.12  GOOGL  Alpabet / Google

# %%
df_GOOGL.plot()

# %%
df_GOOGL.to_csv('../data/GOOGL_Stock.csv')

# %%
import csv
df_datacol = pd.read_csv('../data/stock_5_years_rows.csv')

# %%
df1 = df_datacol

# %%
list(df1)
# Out:
# ['date', 'open', 'high', 'low', 'close', 'volume', 'Name', 'RealName']

# %%
df1["date"] = pd.to_datetime(df1["date"])

# %%
##Date was in a funky column type so imported to make it a filterable column
df1.head()
# Out:
#         date    open     high      low   close   volume  Name RealName
# 0 2014-01-21  171.24  177.290  170.810  176.68  9745765  TSLA    Tesla
# 1 2014-01-22  177.81  180.319  174.760  178.56  7036758  TSLA    Tesla
# 2 2014-01-23  177.23  182.380  173.420  181.50  7899515  TSLA    Tesla
# 3 2014-01-24  177.85  180.480  173.531  174.60  7711296  TSLA    Tesla
# 4 2014-01-27  175.16  177.920  164.710  169.62  8737773  TSLA    Tesla

# %%
df1['dat'] = df1['date'].dt.day

# %%
df1.tail()
# Out:
#             date     open     high      low    close   volume   Name RealName  \
# 17401 2019-01-14  1053.34  1058.45  1048.55  1051.51  1424486  GOOGL   Google
# 17402 2019-01-15  1058.01  1088.27  1054.44  1086.51  1875852  GOOGL   Google
# 17403 2019-01-16  1090.00  1102.36  1088.01  1089.51  1914041  GOOGL   Google
# 17404 2019-01-17  1087.99  1100.70  1083.26  1099.12  1244801  GOOGL   Google
# 17405 2019-01-18  1108.59  1118.00  1099.28  1107.30  2244569  GOOGL   Google
#
#        dat
# 17401   14
# 17402   15
# 17403   16
# 17404   17
# 17405   18

# %%
df1 = df1[df1['dat']== 1]

# %%
df_firstday.tail(5)
# Out:
#                       date         open         high          low  \
# 17246  2018-06-01 00:00:00  1112.870000  1138.160000  1112.010000
# 17288  2018-08-01 00:00:00  1239.110000  1245.900000  1224.940000
# 17330  2018-10-01 00:00:00  1213.000000  1224.200000  1203.190000
# 17353  2018-11-01 00:00:00  1091.400000  1099.900000  1077.820000
# value            0.0939174     0.042616     0.042616     0.042616
#
#              close        volume       Name          RealName       dat  \
# 17246  1135.000000  3.160100e+06      GOOGL  Alpabet / Google  1.000000
# 17288  1232.990000  1.849740e+06      GOOGL  Alpabet / Google  1.000000
# 17330  1208.530000  1.659364e+06      GOOGL  Alpabet / Google  1.000000
# 17353  1085.980000  2.006575e+06      GOOGL  Alpabet / Google  1.000000
# value     0.042616  4.261624e-02  0.0426162         0.0426162  0.042616
#
#               value
# 17246 -7.947348e+00
# 17288  2.023946e+00
# 17330  1.128474e+01
# 17353  2.548178e+06
# value           NaN

# %%
df1['value']= ((df1['close']-df1.shift(-1,axis=0)['close'])/df1.shift(-1,axis=0)['close'])*100

# %%
import numpy as np

df1 = df1[np.isfinite(df1['value'])]
df1.tail(5)
# Out:
#             date     open     high      low    close   volume   Name RealName  \
# 17182 2018-03-01  1109.54  1111.27  1067.29  1071.41  2766856  GOOGL   Google
# 17224 2018-05-01  1016.30  1041.73  1010.61  1040.75  1766256  GOOGL   Google
# 17246 2018-06-01  1112.87  1138.16  1112.01  1135.00  3160100  GOOGL   Google
# 17288 2018-08-01  1239.11  1245.90  1224.94  1232.99  1849740  GOOGL   Google
# 17330 2018-10-01  1213.00  1224.20  1203.19  1208.53  1659364  GOOGL   Google
#
#        dat      value
# 17182    1   2.945952
# 17224    1  -8.303965
# 17246    1  -7.947348
# 17288    1   2.023946
# 17330    1  11.284738

# %%
df1.to_csv('../data/monthlychange.csv')

# %%
df.head()
# Out:
#               open     high      low   close   volume  Name RealName
# date
# 2014-01-21  171.24  177.290  170.810  176.68  9745765  TSLA    Tesla
# 2014-01-22  177.81  180.319  174.760  178.56  7036758  TSLA    Tesla
# 2014-01-23  177.23  182.380  173.420  181.50  7899515  TSLA    Tesla
# 2014-01-24  177.85  180.480  173.531  174.60  7711296  TSLA    Tesla
# 2014-01-27  175.16  177.920  164.710  169.62  8737773  TSLA    Tesla

# %%
dfnew = df_datacol.drop(['high','low','volume','open','Name'],axis=1)
dfnew=dfnew.pivot(index='date', columns='RealName', values='close')

# %%
list(dfnew)
# Out:
# ['Arcimoto',
#  'Ferrari',
#  'Fiat Chrysler',
#  'Ford',
#  'GM',
#  'Google',
#  'Harley Davidson',
#  'Honda',
#  'Kandi Technologies Inc',
#  'NIO',
#  'Nvidia',
#  'Spartan Motors',
#  'Tata Motors',
#  'Tesla',
#  'Toyota',
#  'Workhorse Group Inc']

# %%
dfnew['Arcimoto'].fillna(0, inplace=True)
dfnew['Ferrari'].fillna(0, inplace=True)
dfnew['Fiat Chrysler'].fillna(0, inplace=True)
dfnew['NIO'].fillna(0, inplace=True)

dfnew.head()
# Out:
# RealName    Arcimoto  Ferrari  Fiat Chrysler     Ford       GM    Google  \
# date
# 2014-01-21       0.0      0.0            0.0  12.6217  31.2460  582.4319
# 2014-01-22       0.0      0.0            0.0  12.7294  31.6209  583.0925
# 2014-01-23       0.0      0.0            0.0  12.6371  31.3112  580.6300
# 2014-01-24       0.0      0.0            0.0  12.1756  30.0154  562.4769
# 2014-01-27       0.0      0.0            0.0  12.0833  29.9584  551.1656
#
# RealName    Harley Davidson    Honda  Kandi Technologies Inc  NIO   Nvidia  \
# date
# 2014-01-21          59.1538  34.7440                   13.33  0.0  15.2614
# 2014-01-22          58.5931  34.6481                   13.90  0.0  15.2424
# 2014-01-23          57.7344  33.9677                   13.11  0.0  15.1853
# 2014-01-24          56.0958  33.1477                   12.37  0.0  14.7954
# 2014-01-27          56.2711  33.2175                   11.61  0.0  14.7004
#
# RealName    Spartan Motors  Tata Motors   Tesla    Toyota  Workhorse Group Inc
# date
# 2014-01-21          6.2552      30.6401  176.68  103.2031                1.101
# 2014-01-22          6.2460      31.2079  178.56  104.2569                1.150
# 2014-01-23          6.0882      30.3512  181.50  102.2607                1.200
# 2014-01-24          5.8005      28.7276  174.60  100.9927                1.250
# 2014-01-27          5.6241      27.1438  169.62  100.2645                1.139

# %%
dfnew.to_csv('../data/stock_5_years_columns.csv')
